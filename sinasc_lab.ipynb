# %% [markdown]
# <a href="https://colab.research.google.com/github/robertopcarreiro/Brutal/blob/master/sinasc_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PARTE I - SOBRE OS DADOS

# %% [markdown]
# Os dados que serão utilizados para esse laboratório são os dados do Sistema de Informação sobre Nascidos Vivos – Sinasc. O Sistema de Informações sobre Nascidos Vivos (Sinasc), foi implantado oficialmente a partir de 1990, com o objetivo de coletar dados sobre os nascimentos informados em todo território nacional e fornecer dados sobre natalidade para todos os níveis do Sistema de Saúde. A implantação do Sinasc ocorreu de forma gradual em todas as unidades da Federação e já vem apresentando em muitos municípios, desde o ano de 1994, um número maior de registros do que o publicado pelo IBGE com base nos dados de Cartório de Registro Civil.

# %% [markdown]
# As informações sobre as variáveis encontram-se no arquivo PDF, cujo link segue abaixo:
#
# [https://diaad.s3.sa-east-1.amazonaws.com/sinasc/SINASC+-+Estrutura.pdf](https://diaad.s3.sa-east-1.amazonaws.com/sinasc/SINASC+-+Estrutura.pdf)

# %% [markdown]
# Na versão atual, o dicionário é composto por 69 variáveis. Dentre estas variáveis, encontram-se dados definidos pelos especialistas para permitir gerar informações essenciais sobre as condições de nascimentos no Brasil. Por exemplo, temos:
#
# ![img-1.png](data:image/png;base64,...)
#
# ---
#
# *   63 -> Posição
# *   ESCMAEAGR1 -> Nome do Campo
# *   C -> Tipo da Variável
#
# *   10 -> Tamanho da Variável
#
# *   Escolaridade 2010 agregada. Valores: 00 – Sem Escolaridade; 01 – Fundamental I Incompleto; 02 – Fundamental I Completo; 03 – Fundamental II Incompleto; 04 – Fundamental II Completo; 05 – Ensino Médio Incompleto; 06 – Ensino Médio Completo; 07 – Superior Incompleto; 08 – Superior Completo; 09 – Ignorado; 10 – Fundamental I Incompleto ou Inespecífico; 11 – Fundamental II Incompleto ou Inespecífico; 12 – Ensino Médio Incompleto ou Inespecífico. -> Descrição
#
# *   2013 -> Ano Inicial
#
# *   C -> Tipo Inicial
#
# *   10 -> Tamanho Inicial
#
# ---
# Observação: acessar o arquivo PDF com o dicionário para entender as variáveis que estão disponíveis.

# %% [markdown]
# Os dados foram obitidos no Open Datasus: https://opendatasus.saude.gov.br/dataset/sistema-de-informacao-sobre-nascidos-vivos-sinasc-1996-a-2020

# %% [markdown]
# Os arquivos foram disponibilizados na pasta dados (/content).
#
# Os arquivos correspondem aos anos de 2020 (922 MB), 2019 (963 MB) e 2018 (996 GB). Assim, temos:
#
# *   SINASC_2018.csv
# *   SINASC_2019.csv
# *   SINASC_2020.csv
#
# Os arquivos do tipo CSV - Comma Separated Values são muito utilizados na Ciência de Dados.

# %% [markdown]
# # PARTE 2 - COMO LER OS DADOS

# %% [markdown]
# Utilizaremos a linguagem de programação Python para realizar essa atividade prática. Acessem este [link](https://www.cienciaedados.com/por-que-cientistas-de-dados-escolhem-python/) para saber mais sobre Python e seu uso na Ciencia de Dados.

# %% [markdown]
# Importamos algumas biblioteca que existem para manipular arquivos do tipo CSV.

# %%
import pandas as pd
import csv
from google.colab import drive

# %% [markdown]
# Montar o diretório do seu driver no colab

# %%
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Executamos o comando de leitura do arquivo

# %%
sinasc_pdf_2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sinasc/SINASC_2020.csv',
                              header=0,
                              sep=';',
                              quotechar='"',
                              #dtype={'GESTACAO': 'Int64'} # para conversão de tipos de variáveis
                              )
# Out:
# <ipython-input-3-b99d526bab0e>:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sinasc_pdf_2020 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sinasc/SINASC_2020.csv',

# %% [markdown]
# Agora vamos visualizar os 5 primeiros registros e os 5 úlyimos para validar que o arquivo foi lido corretamente.

# %%
pd.set_option('display.max_columns', 100)
sinasc_pdf_2020.head(-5)
# Out:
#          ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  ESCMAE  \
# 0             1  6205224.0      110020        1      34.0        2.0     5.0
# 1             1        NaN      110020        4      18.0        1.0     9.0
# 2             1  3970442.0      110020        1      26.0        2.0     5.0
# 3             1  5701929.0      120001        1      29.0        5.0     4.0
# 4             1  5701929.0      120001        1      20.0        5.0     4.0
# ...         ...        ...         ...      ...       ...        ...     ...
# 2730135       1  2441888.0      520490        1      32.0        2.0     5.0
# 2730136       1  2441888.0      520490        1      21.0        1.0     4.0
# 2730137       1  2441888.0      520490        1      29.0        2.0     4.0
# 2730138       1  2441888.0      520490        1      33.0        5.0     4.0
# 2730139       1  2441888.0      520490        1      30.0        2.0     5.0
#
#          CODOCUPMAE  QTDFILVIVO  QTDFILMORT  CODMUNRES  GESTACAO  GRAVIDEZ  \
# 0          251605.0         1.0         1.0     120040       5.0       1.0
# 1          999992.0         1.0         0.0     120040       NaN       1.0
# 2          422105.0         NaN         NaN     120040       5.0       1.0
# 3          999992.0         2.0         0.0     120001       5.0       1.0
# 4          999992.0         0.0         1.0     120001       4.0       1.0
# ...             ...         ...         ...        ...       ...       ...
# 2730135    999992.0         1.0         0.0     170240       5.0       1.0
# 2730136    999992.0         0.0         0.0     172090       5.0       1.0
# 2730137    141410.0         1.0         1.0     170555       5.0       1.0
# 2730138    621005.0         3.0         0.0     172090       5.0       1.0
# 2730139         NaN         2.0         0.0     170270       4.0       1.0
#
#          PARTO  CONSULTAS    DTNASC  HORANASC  SEXO  APGAR1  APGAR5  RACACOR  \
# 0          2.0        4.0   3042020    2035.0     2     9.0    10.0      1.0
# 1          1.0        1.0   2052020    2331.0     2     NaN     NaN      4.0
# 2          2.0        4.0   6022020    1020.0     1     9.0     9.0      4.0
# 3          1.0        3.0   6012020    2145.0     1     9.0    10.0      4.0
# 4          1.0        4.0  25012020     940.0     2     4.0     8.0      4.0
# ...        ...        ...       ...       ...   ...     ...     ...      ...
# 2730135    1.0        3.0  19122020    2100.0     1     9.0    10.0      4.0
# 2730136    2.0        4.0  20122020     136.0     2     7.0     9.0      4.0
# 2730137    2.0        4.0  28122020    1738.0     2     9.0    10.0      4.0
# 2730138    2.0        4.0  30122020    1440.0     2     9.0    10.0      4.0
# 2730139    2.0        4.0  14082020    1918.0     1     7.0     8.0      4.0
#
#            PESO  IDANOMAL  DTCADASTRO CODANOMAL  NUMEROLOTE VERSAOSIST  \
# 0        3650.0       2.0    13052020       NaN  20200009.0     3.2.01
# 1        1400.0       2.0    18062020       NaN  20200013.0     3.2.01
# 2        3455.0       NaN    11022020       NaN  20200009.0     3.2.01
# 3        3620.0       2.0     4022022       NaN  20220002.0     3.2.01
# 4        2400.0       2.0     4022022       NaN  20220002.0     3.2.01
# ...         ...       ...         ...       ...         ...        ...
# 2730135  2760.0       2.0     9062021       NaN  20210057.0     3.2.01
# 2730136  2850.0       2.0    13082021       NaN  20210075.0     3.2.01
# 2730137  3130.0       2.0     8062021       NaN  20210057.0     3.2.01
# 2730138  3520.0       2.0     9062021       NaN  20210057.0     3.2.01
# 2730139  1408.0       2.0    10052021       NaN  20210050.0     3.2.01
#
#           DTRECEBIM  DIFDATA  DTRECORIGA  NATURALMAE  CODMUNNATU CODUFNATU  \
# 0        15052020.0       42         NaN       812.0    120040.0      12.0
# 1        23062020.0       52         NaN       812.0    120040.0      12.0
# 2        14022020.0        8         NaN       811.0    110020.0      11.0
# 3        25022022.0      781         NaN       812.0    120001.0      12.0
# 4        25022022.0      762         NaN       812.0    120040.0      12.0
# ...             ...      ...         ...         ...         ...       ...
# 2730135  10062021.0      173         NaN       852.0    520490.0      52.0
# 2730136  16082021.0      239         NaN       829.0    290320.0      29.0
# 2730137  10062021.0      164         NaN       852.0    520490.0      52.0
# 2730138  10062021.0      162         NaN       817.0    172090.0      17.0
# 2730139  11052021.0      270         NaN       817.0    170270.0      17.0
#
#          ESCMAE2010  SERIESCMAE   DTNASCMAE  RACACORMAE  QTDGESTANT  \
# 0               5.0         NaN  21081985.0         1.0         2.0
# 1               9.0         NaN  21102001.0         4.0         1.0
# 2               4.0         NaN   5081993.0         4.0         NaN
# 3               3.0         2.0   6091990.0         4.0         2.0
# 4               2.0         8.0   7071999.0         4.0         1.0
# ...             ...         ...         ...         ...         ...
# 2730135         4.0         NaN  10111988.0         4.0         1.0
# 2730136         2.0         8.0   2021999.0         4.0         0.0
# 2730137         3.0         3.0  17081991.0         4.0         2.0
# 2730138         2.0         8.0  31071987.0         4.0         3.0
# 2730139         5.0         NaN  28041990.0         4.0         2.0
#
#          QTDPARTNOR  QTDPARTCES  IDADEPAI  DTULTMENST  SEMAGESTAC  TPMETESTIM  \
# 0               1.0         1.0       NaN         NaN        38.0         9.0
# 1               1.0         0.0       NaN         NaN         NaN         NaN
# 2               NaN         NaN       NaN         NaN        38.0         9.0
# 3               2.0         0.0       NaN         NaN        39.0         2.0
# 4               0.0         0.0       NaN   2062019.0        33.0         8.0
# ...             ...         ...       ...         ...         ...         ...
# 2730135         1.0         0.0      35.0  26032020.0        38.0         8.0
# 2730136         0.0         0.0      20.0  20032020.0        39.0         8.0
# 2730137         0.0         1.0      38.0   1042020.0        39.0         8.0
# 2730138         3.0         0.0      28.0  25032020.0        40.0         8.0
# 2730139         2.0         0.0      32.0   5122019.0        36.0         8.0
#
#          CONSPRENAT  MESPRENAT  TPAPRESENT  STTRABPART  STCESPARTO  \
# 0               9.0        2.0         1.0         2.0         1.0
# 1               NaN        NaN         1.0         NaN         3.0
# 2              10.0        1.0         1.0         1.0         2.0
# 3               6.0        3.0         1.0         2.0         3.0
# 4               7.0        2.0         2.0         2.0         3.0
# ...             ...        ...         ...         ...         ...
# 2730135         4.0        2.0         1.0         2.0         3.0
# 2730136         7.0        1.0         1.0         2.0         2.0
# 2730137         8.0        2.0         1.0         2.0         2.0
# 2730138         7.0        3.0         1.0         2.0         2.0
# 2730139        11.0        2.0         1.0         2.0         1.0
#
#          TPNASCASSI  TPFUNCRESP  TPDOCRESP  DTDECLARAC  ESCMAEAGR1  \
# 0               1.0         1.0        2.0   3042020.0         8.0
# 1               4.0         2.0        5.0   3052020.0         9.0
# 2               1.0         2.0        3.0   6022020.0         7.0
# 3               1.0         2.0        3.0   7012020.0         5.0
# 4               2.0         2.0        3.0  25012020.0         4.0
# ...             ...         ...        ...         ...         ...
# 2730135         1.0         5.0        0.0  20122020.0         7.0
# 2730136         1.0         5.0        0.0  20122020.0         4.0
# 2730137         1.0         2.0        3.0  29122020.0         6.0
# 2730138         1.0         2.0        3.0  30122020.0         4.0
# 2730139         1.0         2.0        3.0  15082020.0         8.0
#
#          STDNEPIDEM  STDNNOVA  CODPAISRES  TPROBSON  PARIDADE  KOTELCHUCK  \
# 0               0.0         1         1.0         5         1           5
# 1               0.0         1         1.0        11         1           9
# 2               0.0         1         1.0         2         0           5
# 3               0.0         1         1.0         3         1           4
# 4               0.0         1         1.0         7         1           5
# ...             ...       ...         ...       ...       ...         ...
# 2730135         0.0         1         1.0         3         1           3
# 2730136         0.0         1         1.0         1         0           5
# 2730137         0.0         1         1.0         5         1           5
# 2730138         0.0         1         1.0         3         1           5
# 2730139         0.0         1         1.0        10         1           5
#
#          CONTADOR
# 0            7565
# 1            8023
# 2            9017
# 3           13104
# 4           13105
# ...           ...
# 2730135   2700884
# 2730136   2700886
# 2730137   2700894
# 2730138   2701117
# 2730139   2702823
#
# [2730140 rows x 61 columns]

# %% [markdown]
# # PARTE 3 - COMO DESCREVER OS DADOS

# %% [markdown]
# Outra validação interessante para verificar se o arquivo foi lido corretamente é gerar informações sobre as variáveis encontradas e o numero de registros.

# %%
sinasc_pdf_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730145 entries, 0 to 2730144
# Data columns (total 61 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ORIGEM      int64
#  1   CODESTAB    float64
#  2   CODMUNNASC  int64
#  3   LOCNASC     int64
#  4   IDADEMAE    float64
#  5   ESTCIVMAE   float64
#  6   ESCMAE      float64
#  7   CODOCUPMAE  float64
#  8   QTDFILVIVO  float64
#  9   QTDFILMORT  float64
#  10  CODMUNRES   int64
#  11  GESTACAO    float64
#  12  GRAVIDEZ    float64
#  13  PARTO       float64
#  14  CONSULTAS   float64
#  15  DTNASC      int64
#  16  HORANASC    float64
#  17  SEXO        int64
#  18  APGAR1      float64
#  19  APGAR5      float64
#  20  RACACOR     float64
#  21  PESO        float64
#  22  IDANOMAL    float64
#  23  DTCADASTRO  int64
#  24  CODANOMAL   object
#  25  NUMEROLOTE  float64
#  26  VERSAOSIST  object
#  27  DTRECEBIM   float64
#  28  DIFDATA     int64
#  29  DTRECORIGA  float64
#  30  NATURALMAE  float64
#  31  CODMUNNATU  float64
#  32  CODUFNATU   object
#  33  ESCMAE2010  float64
#  34  SERIESCMAE  float64
#  35  DTNASCMAE   float64
#  36  RACACORMAE  float64
#  37  QTDGESTANT  float64
#  38  QTDPARTNOR  float64
#  39  QTDPARTCES  float64
#  40  IDADEPAI    float64
#  41  DTULTMENST  float64
#  42  SEMAGESTAC  float64
#  43  TPMETESTIM  float64
#  44  CONSPRENAT  float64
#  45  MESPRENAT   float64
#  46  TPAPRESENT  float64
#  47  STTRABPART  float64
#  48  STCESPARTO  float64
#  49  TPNASCASSI  float64
#  50  TPFUNCRESP  float64
#  51  TPDOCRESP   float64
#  52  DTDECLARAC  float64
#  53  ESCMAEAGR1  float64
#  54  STDNEPIDEM  float64
#  55  STDNNOVA    int64
#  56  CODPAISRES  float64
#  57  TPROBSON    int64
#  58  PARIDADE    int64
#  59  KOTELCHUCK  int64
#  60  CONTADOR    int64
# dtypes: float64(45), int64(13), object(3)
# memory usage: 1.2+ GB

# %% [markdown]
# Descrever um pouco mais as variáveis.

# %%
sinasc_pdf_2020.describe()
# Out:
#              ORIGEM      CODESTAB    CODMUNNASC       LOCNASC      IDADEMAE  \
# count  2.730145e+06  2.702296e+06  2.730145e+06  2.730145e+06  2.730112e+06
# mean   1.000753e+00  2.952197e+06  3.191264e+05  1.030914e+00  2.721699e+01
# std    2.743186e-02  1.889147e+06  9.955500e+04  2.652407e-01  6.766235e+00
# min    1.000000e+00  1.000000e+00  1.100010e+05  1.000000e+00  1.000000e+01
# 25%    1.000000e+00  2.129469e+06  2.601200e+05  1.000000e+00  2.200000e+01
# 50%    1.000000e+00  2.460017e+06  3.205300e+05  1.000000e+00  2.700000e+01
# 75%    1.000000e+00  2.792141e+06  3.550300e+05  1.000000e+00  3.200000e+01
# max    2.000000e+00  9.999999e+06  5.300100e+05  9.000000e+00  9.900000e+01
#
#           ESTCIVMAE        ESCMAE    CODOCUPMAE    QTDFILVIVO    QTDFILMORT  \
# count  2.714152e+06  2.716439e+06  2.521363e+06  2.666885e+06  2.631571e+06
# mean   2.147996e+00  4.071867e+00  7.212619e+05  1.034417e+00  2.551267e-01
# std    1.550261e+00  7.611141e-01  3.017408e+05  1.320017e+00  7.201863e-01
# min    1.000000e+00  1.000000e+00  1.010500e+04  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  4.000000e+00  4.222050e+05  0.000000e+00  0.000000e+00
# 50%    2.000000e+00  4.000000e+00  8.483100e+05  1.000000e+00  0.000000e+00
# 75%    2.000000e+00  4.000000e+00  9.999920e+05  2.000000e+00  0.000000e+00
# max    9.000000e+00  9.000000e+00  9.999940e+05  9.900000e+01  9.900000e+01
#
#           CODMUNRES      GESTACAO      GRAVIDEZ         PARTO     CONSULTAS  \
# count  2.730145e+06  2.695466e+06  2.727821e+06  2.727982e+06  2.730004e+06
# mean   3.190431e+05  4.885336e+00  1.022357e+00  1.572861e+00  3.645182e+00
# std    9.947837e+04  4.527063e-01  1.560873e-01  4.958856e-01  7.769855e-01
# min    1.100010e+05  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.601200e+05  5.000000e+00  1.000000e+00  1.000000e+00  3.000000e+00
# 50%    3.205200e+05  5.000000e+00  1.000000e+00  2.000000e+00  4.000000e+00
# 75%    3.550300e+05  5.000000e+00  1.000000e+00  2.000000e+00  4.000000e+00
# max    5.300100e+05  9.000000e+00  9.000000e+00  9.000000e+00  9.000000e+00
#
#              DTNASC      HORANASC          SEXO        APGAR1        APGAR5  \
# count  2.730145e+06  2.727786e+06  2.730145e+06  2.689232e+06  2.688609e+06
# mean   1.576183e+07  1.257840e+03  1.487598e+00  8.432623e+00  9.383758e+00
# std    8.786430e+06  6.048057e+02  5.001715e-01  2.782686e+00  2.312890e+00
# min    1.012020e+06  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    8.072020e+06  8.400000e+02  1.000000e+00  8.000000e+00  9.000000e+00
# 50%    1.603202e+07  1.226000e+03  1.000000e+00  9.000000e+00  9.000000e+00
# 75%    2.309202e+07  1.730000e+03  2.000000e+00  9.000000e+00  1.000000e+01
# max    3.112202e+07  1.400000e+04  2.000000e+00  9.900000e+01  9.900000e+01
#
#             RACACOR          PESO      IDANOMAL    DTCADASTRO    NUMEROLOTE  \
# count  2.659264e+06  2.729508e+06  2.708889e+06  2.730145e+06  2.727319e+06
# mean   2.845154e+00  3.194066e+03  2.066590e+00  1.573151e+07  2.020136e+07
# std    1.423164e+00  5.658231e+02  7.289570e-01  8.719901e+06  3.564114e+03
# min    1.000000e+00  1.000000e+02  1.000000e+00  1.012002e+06  2.019003e+07
# 25%    1.000000e+00  2.910000e+03  2.000000e+00  8.072020e+06  2.020001e+07
# 50%    4.000000e+00  3.230000e+03  2.000000e+00  1.601202e+07  2.020002e+07
# 75%    4.000000e+00  3.540000e+03  2.000000e+00  2.309202e+07  2.020005e+07
# max    5.000000e+00  7.000000e+03  9.000000e+00  3.112202e+07  2.022002e+07
#
#           DTRECEBIM       DIFDATA  DTRECORIGA    NATURALMAE    CODMUNNATU  \
# count  2.718554e+06  2.730145e+06         0.0  2.678866e+06  2.678862e+06
# mean   1.668874e+07  6.264473e+01         NaN  8.309728e+02  3.112585e+05
# std    8.728025e+06  1.070373e+02         NaN  9.706688e+00  9.702313e+04
# min    1.022021e+06  0.000000e+00         NaN  5.800000e+01  1.100000e+05
# 25%    1.002202e+07  1.300000e+01         NaN  8.250000e+02  2.504000e+05
# 50%    1.612202e+07  2.400000e+01         NaN  8.310000e+02  3.141500e+05
# 75%    2.411202e+07  5.100000e+01         NaN  8.350000e+02  3.550300e+05
# max    3.112202e+07  7.980000e+02         NaN  8.990000e+02  5.300100e+05
#
#          ESCMAE2010    SERIESCMAE     DTNASCMAE    RACACORMAE    QTDGESTANT  \
# count  2.694344e+06  1.765030e+06  2.702307e+06  2.638502e+06  2.656008e+06
# mean   3.128011e+00  3.922704e+00  1.569629e+07  2.839155e+00  1.267592e+00
# std    1.130712e+00  2.223610e+00  8.779862e+06  1.424235e+00  1.518360e+00
# min    0.000000e+00  1.000000e+00  1.011970e+06  1.000000e+00  0.000000e+00
# 25%    2.000000e+00  3.000000e+00  8.071988e+06  1.000000e+00  0.000000e+00
# 50%    3.000000e+00  3.000000e+00  1.601200e+07  4.000000e+00  1.000000e+00
# 75%    3.000000e+00  6.000000e+00  2.309198e+07  4.000000e+00  2.000000e+00
# max    9.000000e+00  8.000000e+00  3.112201e+07  5.000000e+00  9.900000e+01
#
#          QTDPARTNOR    QTDPARTCES       IDADEPAI    DTULTMENST    SEMAGESTAC  \
# count  2.632345e+06  2.619714e+06  994081.000000  1.367928e+06  2.694806e+06
# mean   6.830583e-01  3.909702e-01      31.834945  1.561544e+07  3.841871e+01
# std    1.319921e+00  8.165277e-01       7.776062  8.663767e+06  2.198956e+00
# min    0.000000e+00  0.000000e+00       1.000000  1.012020e+06  1.900000e+01
# 25%    0.000000e+00  0.000000e+00      26.000000  8.072019e+06  3.800000e+01
# 50%    0.000000e+00  0.000000e+00      31.000000  1.511202e+07  3.900000e+01
# 75%    1.000000e+00  1.000000e+00      37.000000  2.308202e+07  4.000000e+01
# max    9.900000e+01  9.900000e+01      99.000000  3.112202e+07  4.500000e+01
#
#          TPMETESTIM    CONSPRENAT     MESPRENAT    TPAPRESENT    STTRABPART  \
# count  2.694806e+06  2.678484e+06  2.664016e+06  2.700463e+06  2.688366e+06
# mean   5.434440e+00  8.604596e+00  4.942819e+00  1.072443e+00  1.970926e+00
# std    3.280502e+00  7.137264e+00  1.525176e+01  5.386262e-01  9.819823e-01
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.000000e+00  6.000000e+00  2.000000e+00  1.000000e+00  2.000000e+00
# 50%    8.000000e+00  8.000000e+00  2.000000e+00  1.000000e+00  2.000000e+00
# 75%    8.000000e+00  1.000000e+01  3.000000e+00  1.000000e+00  2.000000e+00
# max    9.000000e+00  9.900000e+01  9.900000e+01  9.000000e+00  9.000000e+00
#
#          STCESPARTO    TPNASCASSI    TPFUNCRESP     TPDOCRESP    DTDECLARAC  \
# count  2.691790e+06  2.704749e+06  2.636499e+06  2.707538e+06  2.687340e+06
# mean   2.303828e+00  1.136488e+00  3.011213e+00  3.163629e+00  1.579706e+07
# std    1.327580e+00  4.500257e-01  1.491671e+00  1.162230e+00  8.783230e+06
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00  1.012020e+06
# 25%    1.000000e+00  1.000000e+00  2.000000e+00  3.000000e+00  8.082020e+06
# 50%    2.000000e+00  1.000000e+00  2.000000e+00  3.000000e+00  1.603202e+07
# 75%    3.000000e+00  1.000000e+00  5.000000e+00  4.000000e+00  2.310202e+07
# max    9.000000e+00  9.000000e+00  5.000000e+00  5.000000e+00  3.112202e+07
#
#          ESCMAEAGR1  STDNEPIDEM      STDNNOVA  CODPAISRES      TPROBSON  \
# count  2.694344e+06   2729765.0  2.730145e+06   2730130.0  2.730145e+06
# mean   6.329501e+00         0.0  9.999626e-01         1.0  4.164207e+00
# std    2.566815e+00         0.0  6.112223e-03         0.0  2.767542e+00
# min    0.000000e+00         0.0  0.000000e+00         1.0  1.000000e+00
# 25%    5.000000e+00         0.0  1.000000e+00         1.0  2.000000e+00
# 50%    6.000000e+00         0.0  1.000000e+00         1.0  3.000000e+00
# 75%    8.000000e+00         0.0  1.000000e+00         1.0  5.000000e+00
# max    1.200000e+01         0.0  1.000000e+00         1.0  1.100000e+01
#
#            PARIDADE    KOTELCHUCK      CONTADOR
# count  2.730145e+06  2.730145e+06  2.730145e+06
# mean   6.295296e-01  4.411142e+00  1.365073e+06
# std    4.829308e-01  1.556302e+00  7.881251e+05
# min    0.000000e+00  1.000000e+00  1.000000e+00
# 25%    0.000000e+00  3.000000e+00  6.825370e+05
# 50%    1.000000e+00  5.000000e+00  1.365073e+06
# 75%    1.000000e+00  5.000000e+00  2.047609e+06
# max    1.000000e+00  9.000000e+00  2.730145e+06

# %%
pd.set_option('display.max_rows', 100)
sinasc_pdf_2020.nunique()
# Out:
# ORIGEM              2
# CODESTAB         5501
# CODMUNNASC       3834
# LOCNASC             6
# IDADEMAE           57
# ESTCIVMAE           6
# ESCMAE              6
# CODOCUPMAE       1966
# QTDFILVIVO         23
# QTDFILMORT         26
# CODMUNRES        5585
# GESTACAO            7
# GRAVIDEZ            4
# PARTO               3
# CONSULTAS           5
# DTNASC            366
# HORANASC         1442
# SEXO                3
# APGAR1             12
# APGAR5             12
# RACACOR             5
# PESO             4853
# IDANOMAL            3
# DTCADASTRO        779
# CODANOMAL        3729
# NUMEROLOTE        441
# VERSAOSIST          5
# DTRECEBIM         682
# DIFDATA           799
# DTRECORIGA          0
# NATURALMAE         32
# CODMUNNATU       5565
# CODUFNATU          56
# ESCMAE2010          7
# SERIESCMAE          8
# DTNASCMAE       13812
# RACACORMAE          5
# QTDGESTANT         50
# QTDPARTNOR         51
# QTDPARTCES         31
# IDADEPAI           92
# DTULTMENST        552
# SEMAGESTAC         27
# TPMETESTIM          4
# CONSPRENAT         70
# MESPRENAT          10
# TPAPRESENT          4
# STTRABPART          3
# STCESPARTO          4
# TPNASCASSI          5
# TPFUNCRESP          5
# TPDOCRESP           6
# DTDECLARAC        707
# ESCMAEAGR1         13
# STDNEPIDEM          1
# STDNNOVA            2
# CODPAISRES          1
# TPROBSON           11
# PARIDADE            2
# KOTELCHUCK          6
# CONTADOR      2730145
# dtype: int64

# %% [markdown]
# # PARTE 4 - COMO VISUALIZAR OS DADOS

# %% [markdown]
# Importar as bibliotecas utilizadas para visualização.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %% [markdown]
# Histograma utilizando o número de anos da escolaridade da mãe.

# %%
y = sinasc_pdf_2020['RACACOR'].fillna("0").astype(int)
ax = sns.countplot(y,label="Count")

# %%
y = sinasc_pdf_2020['GESTACAO']
ax = sns.countplot(y,x='class', label="Count")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-c578aad12cc3> in <cell line: 2>()
#       1 y = sinasc_pdf_2020['GESTACAO']
# ----> 2 ax = sns.countplot(y,x='class', label="Count")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2941         raise ValueError("Cannot pass values for both `x` and `y`")
#    2942
# -> 2943     plotter = _CountPlotter(
#    2944         x, y, hue, data, order, hue_order,
#    2945         estimator, errorbar, n_boot, units, seed,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     539                 if isinstance(var, str):
#     540                     err = f"Could not interpret input '{var}'"
# --> 541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'class'

# %%
parto_vaginal = sinasc_pdf_2020[sinasc_pdf_2020['PARTO']==1]['PARTO'].count()
parto_cesario= sinasc_pdf_2020[sinasc_pdf_2020['PARTO']==2]['PARTO'].count()
parto_ignorado= sinasc_pdf_2020[sinasc_pdf_2020['PARTO']==9]['PARTO'].count()

sns.set_theme(palette="dark", font_scale= 1.5)
data = [parto_vaginal, parto_cesario, parto_ignorado]
parto = ['Vaginal', 'Cesário', 'Ignorado']
plt.pie(data, labels=parto, colors = sns.color_palette('Paired')[0:4], autopct='%.0f%%')
plt.show()

# %%
#sns.distplot(sinasc_pdf_2020['PESO'], kde=False);
sns.histplot(sinasc_pdf_2020['PESO'], kde=False);
plt.axvline(0, color="k", linestyle="--");

# %% [markdown]
# # PARTE 5 - SELECIONANDO VARIÁVEIS

# %%
sinasc_pdf_2020[['PESO','SEXO','RACACOR']]
# Out:
#            PESO  SEXO  RACACOR
# 0        3650.0     2      1.0
# 1        1400.0     2      4.0
# 2        3455.0     1      4.0
# 3        3620.0     1      4.0
# 4        2400.0     2      4.0
# ...         ...   ...      ...
# 2730140  2925.0     1      2.0
# 2730141  1628.0     1      4.0
# 2730142  1610.0     2      5.0
# 2730143  3245.0     1      4.0
# 2730144  2855.0     2      NaN
#
# [2730145 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['PESO'].plot(kind='hist', bins=20, title='PESO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['SEXO'].plot(kind='hist', bins=20, title='SEXO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['RACACOR'].plot(kind='hist', bins=20, title='RACACOR')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='PESO', y='SEXO', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='SEXO', y='RACACOR', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['PESO'].plot(kind='line', figsize=(8, 4), title='PESO')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['SEXO'].plot(kind='line', figsize=(8, 4), title='SEXO')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['RACACOR'].plot(kind='line', figsize=(8, 4), title='RACACOR')
# plt.gca().spines[['top', 'right']].set_visible(False)
